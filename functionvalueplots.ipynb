# %%
from matplotlib import pyplot as pylt
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy import stats

# %%
df = pd.read_csv('C:/Users/simon/Desktop/Ergebnisse/function_values_01.csv')

# %%
df.head()
# Out:
#        dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498  2.158968  3.023668  2.460791  1.472241  2.875198  2.411715
# 1  9211751  2.138559  3.139700  2.591174  1.351738  2.621897  2.986014
# 2  9230284  1.649327  2.149240  1.940168  1.506543  2.426222  2.008655
# 3  9156526  1.458304  2.592318  2.481879  1.188826  2.042241  1.949281
# 4  9197994  2.203594  3.796033  3.355781  1.867275  3.542058  3.118243
#
#          pLF        pMF       aLF  ...  cLT.aMiv   eMT.aSD  eMT.aMav  \
# 0  17.244643  18.443767  3.549472  ...  0.825997  0.308603  1.958831
# 1  16.906331  21.490663  4.001567  ...  1.419794  0.298261  1.635736
# 2  16.886554  16.984058  4.310912  ...  1.448673  0.367534  1.514449
# 3  15.803191  16.574328  3.515743  ...  1.111224  0.274254  1.243089
# 4  15.277349  21.334391  4.233532  ...  1.718726  0.351301  1.652335
#
#    eMT.aMiv   iLT.aSD  iLT.aMav  iLT.aMiv   pMF.aSD   pMF.aMav  pMF.aMiv
# 0  0.771453  0.692423  2.816183  0.600781  9.895199  33.467845 -3.448344
# 1  0.546696  0.395460  2.353653  0.894824  9.665277  39.793847 -3.094167
# 2  0.331607  0.647628  3.591207  1.270043  9.558288  30.517192 -2.228660
# 3  0.084920  0.592469  2.861153  0.506999  9.822458  32.965732 -3.018301
# 4  0.259986  0.319893  2.609692  1.311555  9.752709  35.663933 -5.603019
#
# [5 rows x 81 columns]

# %% [markdown]
# Fill NaN values with overall dataset mean.

# %%
#print(f'Filling {df[df.isna().any(axis=1)].shape[0]} instances containing NaN values.')

# %%
#d = defaultdict()
#for column in df.columns:
#    d[column] = df[column].mean()

# %%
#df.fillna(value=d, inplace=True)

# %% [markdown]
# Filter out extreme outliers (deviating more than 5 standard deviations from the mean).

# %%
#numrows = df.shape[0]
#df = df[(np.abs(stats.zscore(df)) < 5).all(axis=1)]
#print(f'Filtered out {numrows - df.shape[0]} instances.')

# %%
df = df.loc[df['dir'] != 9189303].loc[df['dir'] != 9539084]

# %%
df.columns
# Out:
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'ccLF.aSD', 'ccLF.aMav', 'ccLF.aMiv', 'aMT.aSD',
#        'aMT.aMav', 'aMT.aMiv', 'icLF.aSD', 'icLF.aMav', 'icLF.aMiv',
#        'ecMF.aSD', 'ecMF.aMav', 'ecMF.aMiv', 'iMT.aSD', 'iMT.aMav', 'iMT.aMiv',
#        'pLT.aSD', 'pLT.aMav', 'pLT.aMiv', 'pLF.aSD', 'pLF.aMav', 'pLF.aMiv',
#        'pMT.aSD', 'pMT.aMav', 'pMT.aMiv', 'eLT.aSD', 'eLT.aMav', 'eLT.aMiv',
#        'icMF.aSD', 'icMF.aMav', 'icMF.aMiv', 'aLF.aSD', 'aLF.aMav', 'aLF.aMiv',
#        'ccMF.aSD', 'ccMF.aMav', 'ccMF.aMiv', 'cMT.aSD', 'cMT.aMav', 'cMT.aMiv',
#        'aMF.aSD', 'aMF.aMav', 'aMF.aMiv', 'aLT.aSD', 'aLT.aMav', 'aLT.aMiv',
#        'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv', 'cLT.aSD', 'cLT.aMav', 'cLT.aMiv',
#        'eMT.aSD', 'eMT.aMav', 'eMT.aMiv', 'iLT.aSD', 'iLT.aMav', 'iLT.aMiv',
#        'pMF.aSD', 'pMF.aMav', 'pMF.aMiv'],
#       dtype='object')

# %%
eclf = df['ecLF']
cclf = df['ccLF']
iclf = df['icLF']
icmf = df['icMF']
ccmf = df['ccMF']
ecmf = df['ecMF']

elt = df['eLT']
plt = df['pLT']
ilt = df['iLT']
alt = df['aLT']
clt = df['cLT']

emt = df['eMT']
pmt = df['pMT']
imt = df['iMT']
amt = df['aMT']
cmt = df['cMT']

plf = df['pLF']
pmf = df['pMF']
alf = df['aLF']
amf = df['aMF']

# %%
xs = np.arange(0, df.shape[0])
len(xs)
# Out:
# 161

# %% [markdown]
# ## Subregion scatters

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = iclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = icmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ccmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ecmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMF')
for i in range(len(xs)):
    pass

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('plt')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ilt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = clt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = emt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = imt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %% [markdown]
# ## Subregion boxplots

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
eclf.plot.box()
#pylt.boxplot(ys)
q1 = eclf.quantile(.25)
q3 = eclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - eclf.median()):.2f} total deviation from median)')
        
pylt.title('ecLF')
# Out:
# Segmentation 9223980.0 is an outlier (1.08 total deviation from median)
# Segmentation 9241424.0 is an outlier (1.08 total deviation from median)
# Text(0.5, 1.0, 'ecLF')

# %%
ys = cclf.to_numpy()
cclf.plot.box()
#pylt.boxplot(ys)
q1 = cclf.quantile(.25)
q3 = cclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cclf.median()):.2f} total deviation from median)')
        
pylt.title('ccLF')
# Out:
# Text(0.5, 1.0, 'ccLF')

# %%
ys = iclf.to_numpy()
iclf.plot.box()
#pylt.boxplot(ys)
q1 = iclf.quantile(.25)
q3 = iclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - iclf.median()):.2f} total deviation from median)')
        
pylt.title('icLF')
# Out:
# Segmentation 9453274.0 is an outlier (1.43 total deviation from median)
# Segmentation 9080864.0 is an outlier (2.52 total deviation from median)
# Text(0.5, 1.0, 'icLF')

# %%
ys = icmf.to_numpy()
icmf.plot.box()
#pylt.boxplot(ys)
q1 = icmf.quantile(.25)
q3 = icmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - icmf.median()):.2f} total deviation from median)')
        
pylt.title('icMF')
# Out:
# Segmentation 9988421.0 is an outlier (1.40 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.61 total deviation from median)
# Segmentation 9905024.0 is an outlier (1.08 total deviation from median)
# Segmentation 9833489.0 is an outlier (1.08 total deviation from median)
# Segmentation 9467252.0 is an outlier (1.30 total deviation from median)
# Segmentation 9486827.0 is an outlier (1.50 total deviation from median)
# Segmentation 9351479.0 is an outlier (1.04 total deviation from median)
# Segmentation 9036770.0 is an outlier (1.31 total deviation from median)
# Text(0.5, 1.0, 'icMF')

# %%
ys = ccmf.to_numpy()
ccmf.plot.box()
#pylt.boxplot(ys)
q1 = ccmf.quantile(.25)
q3 = ccmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ccmf.median()):.2f} total deviation from median)')
        
pylt.title('ccMF')
# Out:
# Segmentation 9988421.0 is an outlier (1.72 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.65 total deviation from median)
# Segmentation 9905024.0 is an outlier (2.09 total deviation from median)
# Segmentation 9355112.0 is an outlier (1.38 total deviation from median)
# Segmentation 9052956.0 is an outlier (1.37 total deviation from median)
# Text(0.5, 1.0, 'ccMF')

# %%
ys = ecmf.to_numpy()
ecmf.plot.box()
#pylt.boxplot(ys)
q1 = ecmf.quantile(.25)
q3 = ecmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ecmf.median()):.2f} total deviation from median)')
        
pylt.title('ecMF')
# Out:
# Segmentation 9606490.0 is an outlier (1.44 total deviation from median)
# Text(0.5, 1.0, 'ecMF')

# %%
ys = plf.to_numpy()
plf.plot.box()
#pylt.boxplot(ys)
q1 = plf.quantile(.25)
q3 = plf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plf.median()):.2f} total deviation from median)')
        
pylt.title('pLF')
# Out:
# Segmentation 9223980.0 is an outlier (5.21 total deviation from median)
# Segmentation 9606490.0 is an outlier (7.13 total deviation from median)
# Segmentation 9096402.0 is an outlier (5.30 total deviation from median)
# Text(0.5, 1.0, 'pLF')

# %%
ys = pmf.to_numpy()
pmf.plot.box()
#pylt.boxplot(ys)
q1 = pmf.quantile(.25)
q3 = pmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmf.median()):.2f} total deviation from median)')
        
pylt.title('pMF')
# Out:
# Segmentation 9867315.0 is an outlier (6.35 total deviation from median)
# Text(0.5, 1.0, 'pMF')

# %%
ys = alf.to_numpy()
alf.plot.box()
#pylt.boxplot(ys)
q1 = alf.quantile(.25)
q3 = alf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alf.median()):.2f} total deviation from median)')
        
pylt.title('aLF')
# Out:
# Segmentation 9606490.0 is an outlier (1.91 total deviation from median)
# Segmentation 9474901.0 is an outlier (2.89 total deviation from median)
# Segmentation 9302260.0 is an outlier (2.15 total deviation from median)
# Segmentation 9322401.0 is an outlier (1.85 total deviation from median)
# Text(0.5, 1.0, 'aLF')

# %%
ys = amf.to_numpy()
amf.plot.box()
#pylt.boxplot(ys)
q1 = amf.quantile(.25)
q3 = amf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amf.median()):.2f} total deviation from median)')
        
pylt.title('aMF')
# Out:
# Segmentation 9222973.0 is an outlier (1.38 total deviation from median)
# Segmentation 9793168.0 is an outlier (1.37 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.60 total deviation from median)
# Segmentation 9467252.0 is an outlier (1.09 total deviation from median)
# Segmentation 9471287.0 is an outlier (1.29 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.60 total deviation from median)
# Segmentation 9302260.0 is an outlier (3.32 total deviation from median)
# Segmentation 9322401.0 is an outlier (1.73 total deviation from median)
# Segmentation 9006723.0 is an outlier (1.27 total deviation from median)
# Text(0.5, 1.0, 'aMF')

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
elt.plot.box()
#pylt.boxplot(ys)
q1 = elt.quantile(.25)
q3 = elt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - elt.median()):.2f} total deviation from median)')
        
pylt.title('eLT')
# Out:
# Segmentation 9302260.0 is an outlier (1.36 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.81 total deviation from median)
# Text(0.5, 1.0, 'eLT')

# %%
ys = plt.to_numpy()
plt.plot.box()
#pylt.boxplot(ys)
q1 = plt.quantile(.25)
q3 = plt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plt.median()):.2f} total deviation from median)')
        
pylt.title('pLT')
# Out:
# Segmentation 9862541.0 is an outlier (1.22 total deviation from median)
# Text(0.5, 1.0, 'pLT')

# %%
ys = ilt.to_numpy()
ilt.plot.box()
#pylt.boxplot(ys)
q1 = ilt.quantile(.25)
q3 = ilt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ilt.median()):.2f} total deviation from median)')
        
pylt.title('iLT')
# Out:
# Segmentation 9606490.0 is an outlier (1.72 total deviation from median)
# Segmentation 9458093.0 is an outlier (2.01 total deviation from median)
# Segmentation 9122643.0 is an outlier (1.94 total deviation from median)
# Segmentation 9035647.0 is an outlier (1.65 total deviation from median)
# Text(0.5, 1.0, 'iLT')

# %%
ys = alt.to_numpy()
alt.plot.box()
#pylt.boxplot(ys)
q1 = alt.quantile(.25)
q3 = alt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alt.median()):.2f} total deviation from median)')
        
pylt.title('aLT')
# Out:
# Text(0.5, 1.0, 'aLT')

# %%
ys = clt.to_numpy()
clt.plot.box()
#pylt.boxplot(ys)
q1 = clt.quantile(.25)
q3 = clt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - clt.median()):.2f} total deviation from median)')
        
pylt.title('cLT')
# Out:
# Text(0.5, 1.0, 'cLT')

# %%
ys = emt.to_numpy()
emt.plot.box()
#pylt.boxplot(ys)
q1 = emt.quantile(.25)
q3 = emt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - emt.median()):.2f} total deviation from median)')
        
pylt.title('eMT')
# Out:
# Segmentation 9606490.0 is an outlier (0.91 total deviation from median)
# Segmentation 9052956.0 is an outlier (1.25 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.90 total deviation from median)
# Text(0.5, 1.0, 'eMT')

# %%
ys = pmt.to_numpy()
pmt.plot.box()
#pylt.boxplot(ys)
q1 = pmt.quantile(.25)
q3 = pmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmt.median()):.2f} total deviation from median)')
        
pylt.title('pMT')
# Out:
# Segmentation 9504056.0 is an outlier (0.76 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.91 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.91 total deviation from median)
# Text(0.5, 1.0, 'pMT')

# %%
ys = imt.to_numpy()
imt.plot.box()
#pylt.boxplot(ys)
q1 = imt.quantile(.25)
q3 = imt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - imt.median()):.2f} total deviation from median)')
        
pylt.title('iMT')
# Out:
# Segmentation 9223980.0 is an outlier (1.65 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.46 total deviation from median)
# Text(0.5, 1.0, 'iMT')

# %%
ys = amt.to_numpy()
amt.plot.box()
#pylt.boxplot(ys)
q1 = amt.quantile(.25)
q3 = amt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amt.median()):.2f} total deviation from median)')
        
pylt.title('aMT')
# Out:
# Segmentation 9606490.0 is an outlier (1.46 total deviation from median)
# Text(0.5, 1.0, 'aMT')

# %%
ys = cmt.to_numpy()
cmt.plot.box()
#pylt.boxplot(ys)
q1 = cmt.quantile(.25)
q3 = cmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cmt.median()):.2f} total deviation from median)')
        
pylt.title('cMT')
# Out:
# Segmentation 9606490.0 is an outlier (1.16 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.11 total deviation from median)
# Segmentation 9080864.0 is an outlier (1.09 total deviation from median)
# Text(0.5, 1.0, 'cMT')

# %%
df.boxplot(column=['ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
       'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT', 'aMT',
       'cMT'], figsize=(20,20))
# Out:
# <AxesSubplot:>
