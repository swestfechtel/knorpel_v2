# %%
from matplotlib import pyplot as pylt
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy import stats

# %%
df = pd.read_csv('C:/Users/simon/Desktop/Ergebnisse/function_values.csv')

# %%
df.head()
# Out:
#          dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498.0  1.472241  2.875198  2.411715  2.158968  3.023668  2.460791
# 1  9211751.0  1.351738  2.621897  2.986014  2.138559  3.139700  2.591174
# 2  9230284.0  1.506543  2.426222  2.008655  1.649327  2.149240  1.940168
# 3  9156526.0  1.188826  2.042241  1.949281  1.458304  2.592318  2.481879
# 4  9246518.0  1.601121  2.323279  2.179348  2.076030  2.744526  2.371329
#
#         pLF       pMF       aLF  ...  aLF.aMiv  ccMF.aSD  ccMF.aMav  \
# 0  2.933932  3.144884  3.302474  ...  0.663050  0.134116   3.281177
# 1  3.096446  3.618247  3.530713  ...  0.955704  0.215981   3.408817
# 2  3.516182  2.354706  4.328974  ...  0.883895  0.265097   2.790358
# 3  2.984778  2.783818  2.864706  ...  0.713849  0.569672   3.413121
# 4  3.093066  3.327471  3.670027  ...  1.240314  0.318371   3.339338
#
#    ccMF.aMiv   eMT.aSD  eMT.aMav  eMT.aMiv  icMF.aSD  icMF.aMav  icMF.aMiv
# 0   2.670666  0.299519  2.094468  0.947252  0.523656   3.027401   0.830356
# 1   2.505575  0.242647  1.966555  1.020750  0.528224   3.284876   1.007266
# 2   1.689109  0.404791  1.965470  0.587166  0.425255   2.684999   0.846299
# 3   1.433809  0.245113  1.534050  0.632290  0.451116   3.250977   0.885212
# 4   2.287479  0.374398  2.294364  0.893820  0.377143   3.089421   1.136390
#
# [5 rows x 81 columns]

# %% [markdown]
# Fill NaN values with overall dataset mean.

# %%
#print(f'Filling {df[df.isna().any(axis=1)].shape[0]} instances containing NaN values.')

# %%
#d = defaultdict()
#for column in df.columns:
#    d[column] = df[column].mean()

# %%
#df.fillna(value=d, inplace=True)

# %% [markdown]
# Filter out extreme outliers (deviating more than 5 standard deviations from the mean).

# %%
#numrows = df.shape[0]
#df = df[(np.abs(stats.zscore(df)) < 5).all(axis=1)]
#print(f'Filtered out {numrows - df.shape[0]} instances.')

# %%
df = df.loc[df['dir'] != 9189303].loc[df['dir'] != 9539084]

# %%
df.columns
# Out:
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'eLT.aSD', 'eLT.aMav', 'eLT.aMiv', 'cMT.aSD', 'cMT.aMav',
#        'cMT.aMiv', 'iLT.aSD', 'iLT.aMav', 'iLT.aMiv', 'aMT.aSD', 'aMT.aMav',
#        'aMT.aMiv', 'aMF.aSD', 'aMF.aMav', 'aMF.aMiv', 'pLT.aSD', 'pLT.aMav',
#        'pLT.aMiv', 'icLF.aSD', 'icLF.aMav', 'icLF.aMiv', 'cLT.aSD', 'cLT.aMav',
#        'cLT.aMiv', 'iMT.aSD', 'iMT.aMav', 'iMT.aMiv', 'pMF.aSD', 'pMF.aMav',
#        'pMF.aMiv', 'pMT.aSD', 'pMT.aMav', 'pMT.aMiv', 'ecMF.aSD', 'ecMF.aMav',
#        'ecMF.aMiv', 'ccLF.aSD', 'ccLF.aMav', 'ccLF.aMiv', 'pLF.aSD',
#        'pLF.aMav', 'pLF.aMiv', 'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv', 'aLT.aSD',
#        'aLT.aMav', 'aLT.aMiv', 'aLF.aSD', 'aLF.aMav', 'aLF.aMiv', 'ccMF.aSD',
#        'ccMF.aMav', 'ccMF.aMiv', 'eMT.aSD', 'eMT.aMav', 'eMT.aMiv', 'icMF.aSD',
#        'icMF.aMav', 'icMF.aMiv'],
#       dtype='object')

# %%
eclf = df['ecLF']
cclf = df['ccLF']
iclf = df['icLF']
icmf = df['icMF']
ccmf = df['ccMF']
ecmf = df['ecMF']

elt = df['eLT']
plt = df['pLT']
ilt = df['iLT']
alt = df['aLT']
clt = df['cLT']

emt = df['eMT']
pmt = df['pMT']
imt = df['iMT']
amt = df['aMT']
cmt = df['cMT']

plf = df['pLF']
pmf = df['pMF']
alf = df['aLF']
amf = df['aMF']

# %%
xs = np.arange(0, df.shape[0])
len(xs)
# Out:
# 505

# %% [markdown]
# # Mesh

# %% [markdown]
# ## Subregion scatters

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = iclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = icmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ccmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ecmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMF')
for i in range(len(xs)):
    pass

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('plt')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ilt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = clt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = emt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = imt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %% [markdown]
# ## Subregion boxplots

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
eclf.plot.box()
#pylt.boxplot(ys)
q1 = eclf.quantile(.25)
q3 = eclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - eclf.median()):.2f} total deviation from median)')
        
pylt.title('ecLF')
# Out:
# Segmentation 9750090.0 is an outlier (1.52 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.45 total deviation from median)
# Segmentation 9604541.0 is an outlier (1.34 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.53 total deviation from median)
# Segmentation 9102858.0 is an outlier (1.26 total deviation from median)
# Segmentation 9030718.0 is an outlier (1.33 total deviation from median)
# Segmentation 9130672.0 is an outlier (1.24 total deviation from median)
# Text(0.5, 1.0, 'ecLF')

# %%
ys = cclf.to_numpy()
cclf.plot.box()
#pylt.boxplot(ys)
q1 = cclf.quantile(.25)
q3 = cclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cclf.median()):.2f} total deviation from median)')
        
pylt.title('ccLF')
# Out:
# Segmentation 9943227.0 is an outlier (2.07 total deviation from median)
# Segmentation 9078486.0 is an outlier (2.08 total deviation from median)
# Text(0.5, 1.0, 'ccLF')

# %%
ys = iclf.to_numpy()
iclf.plot.box()
#pylt.boxplot(ys)
q1 = iclf.quantile(.25)
q3 = iclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - iclf.median()):.2f} total deviation from median)')
        
pylt.title('icLF')
# Out:
# Segmentation 9215922.0 is an outlier (1.84 total deviation from median)
# Segmentation 9242457.0 is an outlier (2.11 total deviation from median)
# Segmentation 9943227.0 is an outlier (1.92 total deviation from median)
# Segmentation 9908089.0 is an outlier (1.54 total deviation from median)
# Segmentation 9745458.0 is an outlier (1.76 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.73 total deviation from median)
# Segmentation 9441432.0 is an outlier (1.80 total deviation from median)
# Segmentation 9413071.0 is an outlier (1.50 total deviation from median)
# Segmentation 9044005.0 is an outlier (1.49 total deviation from median)
# Segmentation 9101066.0 is an outlier (1.47 total deviation from median)
# Text(0.5, 1.0, 'icLF')

# %%
ys = icmf.to_numpy()
icmf.plot.box()
#pylt.boxplot(ys)
q1 = icmf.quantile(.25)
q3 = icmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - icmf.median()):.2f} total deviation from median)')
        
pylt.title('icMF')
# Out:
# Segmentation 9180558.0 is an outlier (1.23 total deviation from median)
# Segmentation 9256759.0 is an outlier (1.41 total deviation from median)
# Segmentation 9672573.0 is an outlier (1.46 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.33 total deviation from median)
# Segmentation 9517311.0 is an outlier (1.78 total deviation from median)
# Segmentation 9453274.0 is an outlier (1.56 total deviation from median)
# Segmentation 9407052.0 is an outlier (1.32 total deviation from median)
# Segmentation 9329062.0 is an outlier (2.14 total deviation from median)
# Segmentation 9393987.0 is an outlier (1.60 total deviation from median)
# Segmentation 9049223.0 is an outlier (1.80 total deviation from median)
# Segmentation 9091131.0 is an outlier (1.51 total deviation from median)
# Segmentation 9080864.0 is an outlier (2.66 total deviation from median)
# Text(0.5, 1.0, 'icMF')

# %%
ys = ccmf.to_numpy()
ccmf.plot.box()
#pylt.boxplot(ys)
q1 = ccmf.quantile(.25)
q3 = ccmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ccmf.median()):.2f} total deviation from median)')
        
pylt.title('ccMF')
# Out:
# Segmentation 9241424.0 is an outlier (1.84 total deviation from median)
# Segmentation 9858216.0 is an outlier (1.71 total deviation from median)
# Segmentation 9781749.0 is an outlier (2.13 total deviation from median)
# Segmentation 9672573.0 is an outlier (1.75 total deviation from median)
# Segmentation 9691663.0 is an outlier (1.69 total deviation from median)
# Segmentation 9517311.0 is an outlier (2.05 total deviation from median)
# Segmentation 9375317.0 is an outlier (2.18 total deviation from median)
# Segmentation 9329062.0 is an outlier (2.56 total deviation from median)
# Segmentation 9371267.0 is an outlier (1.70 total deviation from median)
# Segmentation 9393987.0 is an outlier (1.89 total deviation from median)
# Segmentation 9048192.0 is an outlier (2.08 total deviation from median)
# Text(0.5, 1.0, 'ccMF')

# %%
ys = ecmf.to_numpy()
ecmf.plot.box()
#pylt.boxplot(ys)
q1 = ecmf.quantile(.25)
q3 = ecmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ecmf.median()):.2f} total deviation from median)')
        
pylt.title('ecMF')
# Out:
# Segmentation 9223980.0 is an outlier (1.15 total deviation from median)
# Segmentation 9204055.0 is an outlier (1.14 total deviation from median)
# Segmentation 9249025.0 is an outlier (1.51 total deviation from median)
# Segmentation 9241424.0 is an outlier (1.14 total deviation from median)
# Segmentation 9781749.0 is an outlier (1.23 total deviation from median)
# Segmentation 9760079.0 is an outlier (1.26 total deviation from median)
# Segmentation 9691663.0 is an outlier (1.37 total deviation from median)
# Segmentation 9481413.0 is an outlier (1.20 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.15 total deviation from median)
# Segmentation 9375317.0 is an outlier (1.61 total deviation from median)
# Segmentation 9393987.0 is an outlier (1.32 total deviation from median)
# Segmentation 9048192.0 is an outlier (1.25 total deviation from median)
# Segmentation 9139557.0 is an outlier (1.29 total deviation from median)
# Text(0.5, 1.0, 'ecMF')

# %%
ys = plf.to_numpy()
plf.plot.box()
#pylt.boxplot(ys)
q1 = plf.quantile(.25)
q3 = plf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plf.median()):.2f} total deviation from median)')
        
pylt.title('pLF')
# Out:
# Segmentation 9211049.0 is an outlier (0.94 total deviation from median)
# Segmentation 9160801.0 is an outlier (1.49 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.47 total deviation from median)
# Segmentation 9987407.0 is an outlier (0.93 total deviation from median)
# Segmentation 9766939.0 is an outlier (0.93 total deviation from median)
# Segmentation 9468561.0 is an outlier (0.93 total deviation from median)
# Segmentation 9445105.0 is an outlier (1.08 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.15 total deviation from median)
# Segmentation 9504935.0 is an outlier (0.88 total deviation from median)
# Segmentation 9494867.0 is an outlier (0.89 total deviation from median)
# Segmentation 9276684.0 is an outlier (0.94 total deviation from median)
# Segmentation 9397988.0 is an outlier (1.65 total deviation from median)
# Segmentation 9395979.0 is an outlier (1.97 total deviation from median)
# Segmentation 9316108.0 is an outlier (1.06 total deviation from median)
# Segmentation 9343449.0 is an outlier (1.39 total deviation from median)
# Segmentation 9120941.0 is an outlier (1.07 total deviation from median)
# Segmentation 9116298.0 is an outlier (0.96 total deviation from median)
# Segmentation 9130672.0 is an outlier (1.06 total deviation from median)
# Text(0.5, 1.0, 'pLF')

# %%
ys = pmf.to_numpy()
pmf.plot.box()
#pylt.boxplot(ys)
q1 = pmf.quantile(.25)
q3 = pmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmf.median()):.2f} total deviation from median)')
        
pylt.title('pMF')
# Out:
# Segmentation 9222973.0 is an outlier (1.70 total deviation from median)
# Segmentation 9598683.0 is an outlier (1.89 total deviation from median)
# Segmentation 9493245.0 is an outlier (4.12 total deviation from median)
# Segmentation 9282257.0 is an outlier (2.19 total deviation from median)
# Segmentation 9371094.0 is an outlier (2.21 total deviation from median)
# Segmentation 9273362.0 is an outlier (1.60 total deviation from median)
# Text(0.5, 1.0, 'pMF')

# %%
ys = alf.to_numpy()
alf.plot.box()
#pylt.boxplot(ys)
q1 = alf.quantile(.25)
q3 = alf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alf.median()):.2f} total deviation from median)')
        
pylt.title('aLF')
# Out:
# Segmentation 9211869.0 is an outlier (2.45 total deviation from median)
# Segmentation 9162394.0 is an outlier (1.63 total deviation from median)
# Segmentation 9817241.0 is an outlier (2.23 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.51 total deviation from median)
# Segmentation 9474571.0 is an outlier (1.65 total deviation from median)
# Segmentation 9518765.0 is an outlier (1.79 total deviation from median)
# Segmentation 9457264.0 is an outlier (1.65 total deviation from median)
# Segmentation 9526396.0 is an outlier (1.49 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.99 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.50 total deviation from median)
# Segmentation 9493245.0 is an outlier (1.87 total deviation from median)
# Segmentation 9302260.0 is an outlier (3.23 total deviation from median)
# Segmentation 9369286.0 is an outlier (1.81 total deviation from median)
# Segmentation 9395979.0 is an outlier (2.30 total deviation from median)
# Segmentation 9322401.0 is an outlier (1.63 total deviation from median)
# Segmentation 9323079.0 is an outlier (3.08 total deviation from median)
# Segmentation 9343449.0 is an outlier (2.79 total deviation from median)
# Segmentation 9143312.0 is an outlier (1.93 total deviation from median)
# Text(0.5, 1.0, 'aLF')

# %%
ys = amf.to_numpy()
amf.plot.box()
#pylt.boxplot(ys)
q1 = amf.quantile(.25)
q3 = amf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amf.median()):.2f} total deviation from median)')
        
pylt.title('aMF')
# Out:
# Segmentation 9214395.0 is an outlier (2.56 total deviation from median)
# Segmentation 9695135.0 is an outlier (3.09 total deviation from median)
# Segmentation 9878871.0 is an outlier (2.61 total deviation from median)
# Segmentation 9518765.0 is an outlier (2.64 total deviation from median)
# Segmentation 9474901.0 is an outlier (3.04 total deviation from median)
# Segmentation 9409032.0 is an outlier (2.43 total deviation from median)
# Segmentation 9493245.0 is an outlier (2.36 total deviation from median)
# Segmentation 9395979.0 is an outlier (2.82 total deviation from median)
# Segmentation 9323079.0 is an outlier (2.49 total deviation from median)
# Segmentation 9343449.0 is an outlier (2.68 total deviation from median)
# Segmentation 9143312.0 is an outlier (2.55 total deviation from median)
# Segmentation 9130672.0 is an outlier (2.50 total deviation from median)
# Text(0.5, 1.0, 'aMF')

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
elt.plot.box()
#pylt.boxplot(ys)
q1 = elt.quantile(.25)
q3 = elt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - elt.median()):.2f} total deviation from median)')
        
pylt.title('eLT')
# Out:
# Segmentation 9223789.0 is an outlier (1.05 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.91 total deviation from median)
# Segmentation 9395979.0 is an outlier (0.89 total deviation from median)
# Segmentation 9388068.0 is an outlier (0.85 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.90 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.80 total deviation from median)
# Segmentation 9130672.0 is an outlier (1.10 total deviation from median)
# Text(0.5, 1.0, 'eLT')

# %%
ys = plt.to_numpy()
plt.plot.box()
#pylt.boxplot(ys)
q1 = plt.quantile(.25)
q3 = plt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plt.median()):.2f} total deviation from median)')
        
pylt.title('pLT')
# Out:
# Segmentation 9154793.0 is an outlier (1.02 total deviation from median)
# Segmentation 9258562.0 is an outlier (1.08 total deviation from median)
# Segmentation 9152295.0 is an outlier (0.91 total deviation from median)
# Segmentation 9686590.0 is an outlier (0.91 total deviation from median)
# Segmentation 9933836.0 is an outlier (0.92 total deviation from median)
# Segmentation 9518267.0 is an outlier (0.98 total deviation from median)
# Segmentation 9314341.0 is an outlier (1.24 total deviation from median)
# Segmentation 9323079.0 is an outlier (1.05 total deviation from median)
# Text(0.5, 1.0, 'pLT')

# %%
ys = ilt.to_numpy()
ilt.plot.box()
#pylt.boxplot(ys)
q1 = ilt.quantile(.25)
q3 = ilt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ilt.median()):.2f} total deviation from median)')
        
pylt.title('iLT')
# Out:
# Segmentation 9154793.0 is an outlier (1.61 total deviation from median)
# Segmentation 9987407.0 is an outlier (1.79 total deviation from median)
# Segmentation 9686590.0 is an outlier (1.64 total deviation from median)
# Segmentation 9468561.0 is an outlier (1.69 total deviation from median)
# Segmentation 9332345.0 is an outlier (1.53 total deviation from median)
# Segmentation 9094693.0 is an outlier (1.73 total deviation from median)
# Text(0.5, 1.0, 'iLT')

# %%
ys = alt.to_numpy()
alt.plot.box()
#pylt.boxplot(ys)
q1 = alt.quantile(.25)
q3 = alt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alt.median()):.2f} total deviation from median)')
        
pylt.title('aLT')
# Out:
# Segmentation 9249025.0 is an outlier (1.43 total deviation from median)
# Segmentation 9468561.0 is an outlier (1.38 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.47 total deviation from median)
# Segmentation 9494867.0 is an outlier (1.85 total deviation from median)
# Segmentation 9493245.0 is an outlier (1.45 total deviation from median)
# Segmentation 9395979.0 is an outlier (1.50 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.41 total deviation from median)
# Text(0.5, 1.0, 'aLT')

# %%
ys = clt.to_numpy()
clt.plot.box()
#pylt.boxplot(ys)
q1 = clt.quantile(.25)
q3 = clt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - clt.median()):.2f} total deviation from median)')
        
pylt.title('cLT')
# Out:
# Segmentation 9258562.0 is an outlier (1.41 total deviation from median)
# Segmentation 9817241.0 is an outlier (1.83 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.71 total deviation from median)
# Text(0.5, 1.0, 'cLT')

# %%
ys = emt.to_numpy()
emt.plot.box()
#pylt.boxplot(ys)
q1 = emt.quantile(.25)
q3 = emt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - emt.median()):.2f} total deviation from median)')
        
pylt.title('eMT')
# Out:
# Segmentation 9154793.0 is an outlier (1.38 total deviation from median)
# Segmentation 9249025.0 is an outlier (1.23 total deviation from median)
# Segmentation 9518267.0 is an outlier (1.15 total deviation from median)
# Segmentation 9534875.0 is an outlier (1.07 total deviation from median)
# Segmentation 9410941.0 is an outlier (1.00 total deviation from median)
# Segmentation 9493245.0 is an outlier (0.96 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.36 total deviation from median)
# Segmentation 9311328.0 is an outlier (1.14 total deviation from median)
# Text(0.5, 1.0, 'eMT')

# %%
ys = pmt.to_numpy()
pmt.plot.box()
#pylt.boxplot(ys)
q1 = pmt.quantile(.25)
q3 = pmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmt.median()):.2f} total deviation from median)')
        
pylt.title('pMT')
# Out:
# Segmentation 9154793.0 is an outlier (1.82 total deviation from median)
# Segmentation 9249025.0 is an outlier (1.24 total deviation from median)
# Segmentation 9862541.0 is an outlier (1.33 total deviation from median)
# Segmentation 9518267.0 is an outlier (1.24 total deviation from median)
# Segmentation 9319367.0 is an outlier (1.53 total deviation from median)
# Text(0.5, 1.0, 'pMT')

# %%
ys = imt.to_numpy()
imt.plot.box()
#pylt.boxplot(ys)
q1 = imt.quantile(.25)
q3 = imt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - imt.median()):.2f} total deviation from median)')
        
pylt.title('iMT')
# Out:
# Segmentation 9154793.0 is an outlier (2.12 total deviation from median)
# Segmentation 9458093.0 is an outlier (1.99 total deviation from median)
# Segmentation 9534875.0 is an outlier (1.80 total deviation from median)
# Segmentation 9122643.0 is an outlier (1.92 total deviation from median)
# Text(0.5, 1.0, 'iMT')

# %%
ys = amt.to_numpy()
amt.plot.box()
#pylt.boxplot(ys)
q1 = amt.quantile(.25)
q3 = amt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amt.median()):.2f} total deviation from median)')
        
pylt.title('aMT')
# Out:
# Segmentation 9249025.0 is an outlier (1.63 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.76 total deviation from median)
# Text(0.5, 1.0, 'aMT')

# %%
ys = cmt.to_numpy()
cmt.plot.box()
#pylt.boxplot(ys)
q1 = cmt.quantile(.25)
q3 = cmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cmt.median()):.2f} total deviation from median)')
        
pylt.title('cMT')
# Out:
# Segmentation 9154793.0 is an outlier (2.64 total deviation from median)
# Segmentation 9518267.0 is an outlier (2.66 total deviation from median)
# Text(0.5, 1.0, 'cMT')

# %%
df.boxplot(column=['ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
       'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT', 'aMT',
       'cMT'], figsize=(20,20))
# Out:
# <AxesSubplot:>
