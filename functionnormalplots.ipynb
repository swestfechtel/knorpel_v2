# %%
from matplotlib import pyplot as pylt
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy import stats

# %%
df = pd.read_csv('C:/Users/simon/Desktop/Ergebnisse/function_normals_01.csv')

# %%
df.head()
# Out:
#        dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498  2.069139  2.916025  1.976808  1.612626  2.423014  1.470498
# 1  9211751  1.868150  2.879939  2.024902  1.438413  2.482691  1.804538
# 2  9230284  1.675049  1.978149  1.461626  1.464516  2.307128  1.249868
# 3  9156526  1.393183  2.289310  2.037210  1.258032  2.036302  1.529223
# 4  9197994  2.003260  3.346352  2.369594  1.808771  2.940873  1.449021
#
#         pLF       pMF       aLF  ...  iMT.aMiv   pLF.aSD  pLF.aMav  pLF.aMiv  \
# 0  2.533704  2.380102  2.060932  ...  0.364583  0.651556  3.920314  0.660118
# 1  2.534477  2.491320  2.308903  ...  0.461233  0.681245  4.082424  0.701306
# 2  1.901357  2.586573  2.618153  ...  0.678931  0.432494  3.188340  0.673021
# 3  2.294731  2.307965  2.001159  ...  0.364583  0.676810  4.072980  0.411775
# 4  2.679630  2.455849  2.374646  ...  0.364583  0.744661  4.516257  0.618663
#
#     pMF.aSD  pMF.aMav  pMF.aMiv   pMT.aSD  pMT.aMav  pMT.aMiv
# 0  0.712034  4.158100  0.784882  0.356797  2.422385  0.689786
# 1  0.664119  4.284358  1.028128  0.399094  2.300828  0.566766
# 2  0.736115  4.007169  0.557283  0.458425  2.008682  0.364584
# 3  0.696848  4.204713  0.822910  0.236861  1.544793  0.523917
# 4  0.631056  4.009897  0.792637  0.332854  2.046094  0.641773
#
# [5 rows x 81 columns]
#        dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498  2.069139  2.916025  1.976808  1.612626  2.423014  1.470498
# 1  9211751  1.868150  2.879939  2.024902  1.438413  2.482691  1.804538
# 2  9230284  1.675049  1.978149  1.461626  1.464516  2.307128  1.249868
# 3  9156526  1.393183  2.289310  2.037210  1.258032  2.036302  1.529223
# 4  9197994  2.003260  3.346352  2.369594  1.808771  2.940873  1.449021
#
#         pLF       pMF       aLF  ...  iMT.aMiv   pLF.aSD  pLF.aMav  pLF.aMiv  \
# 0  2.533704  2.380102  2.060932  ...  0.364583  0.651556  3.920314  0.660118
# 1  2.534477  2.491320  2.308903  ...  0.461233  0.681245  4.082424  0.701306
# 2  1.901357  2.586573  2.618153  ...  0.678931  0.432494  3.188340  0.673021
# 3  2.294731  2.307965  2.001159  ...  0.364583  0.676810  4.072980  0.411775
# 4  2.679630  2.455849  2.374646  ...  0.364583  0.744661  4.516257  0.618663
#
#     pMF.aSD  pMF.aMav  pMF.aMiv   pMT.aSD  pMT.aMav  pMT.aMiv
# 0  0.712034  4.158100  0.784882  0.356797  2.422385  0.689786
# 1  0.664119  4.284358  1.028128  0.399094  2.300828  0.566766
# 2  0.736115  4.007169  0.557283  0.458425  2.008682  0.364584
# 3  0.696848  4.204713  0.822910  0.236861  1.544793  0.523917
# 4  0.631056  4.009897  0.792637  0.332854  2.046094  0.641773
#
# [5 rows x 81 columns]

# %% [markdown]
# Fill NaN values with overall dataset mean.

# %%
#print(f'Filling {df[df.isna().any(axis=1)].shape[0]} instances containing NaN values.')

# %%
#d = defaultdict()
#for column in df.columns:
#    d[column] = df[column].mean()

# %%
#df.fillna(value=d, inplace=True)

# %% [markdown]
# Filter out extreme outliers (deviating more than 5 standard deviations from the mean).

# %%
#numrows = df.shape[0]
#df = df[(np.abs(stats.zscore(df)) < 5).all(axis=1)]
#print(f'Filtered out {numrows - df.shape[0]} instances.')

# %%
#df = df.loc[df['dir'] != 9189303].loc[df['dir'] != 9539084]

# %%
df.columns
# Out:
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'aLT.aSD', 'aLT.aMav', 'aLT.aMiv', 'aMT.aSD', 'aMT.aMav',
#        'aMT.aMiv', 'icLF.aSD', 'icLF.aMav', 'icLF.aMiv', 'aMF.aSD', 'aMF.aMav',
#        'aMF.aMiv', 'pLT.aSD', 'pLT.aMav', 'pLT.aMiv', 'cLT.aSD', 'cLT.aMav',
#        'cLT.aMiv', 'iLT.aSD', 'iLT.aMav', 'iLT.aMiv', 'eMT.aSD', 'eMT.aMav',
#        'eMT.aMiv', 'icMF.aSD', 'icMF.aMav', 'icMF.aMiv', 'ccMF.aSD',
#        'ccMF.aMav', 'ccMF.aMiv', 'ecMF.aSD', 'ecMF.aMav', 'ecMF.aMiv',
#        'aLF.aSD', 'aLF.aMav', 'aLF.aMiv', 'ccLF.aSD', 'ccLF.aMav', 'ccLF.aMiv',
#        'cMT.aSD', 'cMT.aMav', 'cMT.aMiv', 'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv',
#        'eLT.aSD', 'eLT.aMav', 'eLT.aMiv', 'iMT.aSD', 'iMT.aMav', 'iMT.aMiv',
#        'pLF.aSD', 'pLF.aMav', 'pLF.aMiv', 'pMF.aSD', 'pMF.aMav', 'pMF.aMiv',
#        'pMT.aSD', 'pMT.aMav', 'pMT.aMiv'],
#       dtype='object')
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'aLT.aSD', 'aLT.aMav', 'aLT.aMiv', 'aMT.aSD', 'aMT.aMav',
#        'aMT.aMiv', 'icLF.aSD', 'icLF.aMav', 'icLF.aMiv', 'aMF.aSD', 'aMF.aMav',
#        'aMF.aMiv', 'pLT.aSD', 'pLT.aMav', 'pLT.aMiv', 'cLT.aSD', 'cLT.aMav',
#        'cLT.aMiv', 'iLT.aSD', 'iLT.aMav', 'iLT.aMiv', 'eMT.aSD', 'eMT.aMav',
#        'eMT.aMiv', 'icMF.aSD', 'icMF.aMav', 'icMF.aMiv', 'ccMF.aSD',
#        'ccMF.aMav', 'ccMF.aMiv', 'ecMF.aSD', 'ecMF.aMav', 'ecMF.aMiv',
#        'aLF.aSD', 'aLF.aMav', 'aLF.aMiv', 'ccLF.aSD', 'ccLF.aMav', 'ccLF.aMiv',
#        'cMT.aSD', 'cMT.aMav', 'cMT.aMiv', 'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv',
#        'eLT.aSD', 'eLT.aMav', 'eLT.aMiv', 'iMT.aSD', 'iMT.aMav', 'iMT.aMiv',
#        'pLF.aSD', 'pLF.aMav', 'pLF.aMiv', 'pMF.aSD', 'pMF.aMav', 'pMF.aMiv',
#        'pMT.aSD', 'pMT.aMav', 'pMT.aMiv'],
#       dtype='object')

# %%
eclf = df['ecLF']
cclf = df['ccLF']
iclf = df['icLF']
icmf = df['icMF']
ccmf = df['ccMF']
ecmf = df['ecMF']

elt = df['eLT']
plt = df['pLT']
ilt = df['iLT']
alt = df['aLT']
clt = df['cLT']

emt = df['eMT']
pmt = df['pMT']
imt = df['iMT']
amt = df['aMT']
cmt = df['cMT']

plf = df['pLF']
pmf = df['pMF']
alf = df['aLF']
amf = df['aMF']

# %%
xs = np.arange(0, df.shape[0])
len(xs)
# Out:
# 161
# 161

# %% [markdown]
# ## Subregion scatters

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = iclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = icmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ccmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ecmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMF')
for i in range(len(xs)):
    pass

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('plt')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ilt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = clt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = emt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = imt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %% [markdown]
# ## Subregion boxplots

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
eclf.plot.box()
#pylt.boxplot(ys)
q1 = eclf.quantile(.25)
q3 = eclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - eclf.median()):.2f} total deviation from median)')
        
pylt.title('ecLF')
# Out:
# Segmentation 9241424.0 is an outlier (1.08 total deviation from median)
# Segmentation 9241424.0 is an outlier (1.08 total deviation from median)
# Text(0.5, 1.0, 'ecLF')
# Text(0.5, 1.0, 'ecLF')

# %%
ys = cclf.to_numpy()
cclf.plot.box()
#pylt.boxplot(ys)
q1 = cclf.quantile(.25)
q3 = cclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cclf.median()):.2f} total deviation from median)')
        
pylt.title('ccLF')
# Out:
# Segmentation 9241424.0 is an outlier (1.61 total deviation from median)
# Segmentation 9241424.0 is an outlier (1.61 total deviation from median)
# Text(0.5, 1.0, 'ccLF')
# Text(0.5, 1.0, 'ccLF')

# %%
ys = iclf.to_numpy()
iclf.plot.box()
#pylt.boxplot(ys)
q1 = iclf.quantile(.25)
q3 = iclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - iclf.median()):.2f} total deviation from median)')
        
pylt.title('icLF')
# Out:
# Segmentation 9180558.0 is an outlier (1.03 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.83 total deviation from median)
# Segmentation 9180558.0 is an outlier (1.03 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.83 total deviation from median)
# Text(0.5, 1.0, 'icLF')
# Text(0.5, 1.0, 'icLF')

# %%
ys = icmf.to_numpy()
icmf.plot.box()
#pylt.boxplot(ys)
q1 = icmf.quantile(.25)
q3 = icmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - icmf.median()):.2f} total deviation from median)')
        
pylt.title('icMF')
# Out:
# Segmentation 9988421.0 is an outlier (0.98 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.26 total deviation from median)
# Segmentation 9905024.0 is an outlier (0.91 total deviation from median)
# Segmentation 9486827.0 is an outlier (0.94 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.89 total deviation from median)
# Segmentation 9988421.0 is an outlier (0.98 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.26 total deviation from median)
# Segmentation 9905024.0 is an outlier (0.91 total deviation from median)
# Segmentation 9486827.0 is an outlier (0.94 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.89 total deviation from median)
# Text(0.5, 1.0, 'icMF')
# Text(0.5, 1.0, 'icMF')

# %%
ys = ccmf.to_numpy()
ccmf.plot.box()
#pylt.boxplot(ys)
q1 = ccmf.quantile(.25)
q3 = ccmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ccmf.median()):.2f} total deviation from median)')
        
pylt.title('ccMF')
# Out:
# Segmentation 9988421.0 is an outlier (1.54 total deviation from median)
# Segmentation 9995338.0 is an outlier (1.08 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.52 total deviation from median)
# Segmentation 9905024.0 is an outlier (1.81 total deviation from median)
# Segmentation 9486827.0 is an outlier (1.23 total deviation from median)
# Segmentation 9355112.0 is an outlier (1.27 total deviation from median)
# Segmentation 9052956.0 is an outlier (1.37 total deviation from median)
# Segmentation 9988421.0 is an outlier (1.54 total deviation from median)
# Segmentation 9995338.0 is an outlier (1.08 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.52 total deviation from median)
# Segmentation 9905024.0 is an outlier (1.81 total deviation from median)
# Segmentation 9486827.0 is an outlier (1.23 total deviation from median)
# Segmentation 9355112.0 is an outlier (1.27 total deviation from median)
# Segmentation 9052956.0 is an outlier (1.37 total deviation from median)
# Text(0.5, 1.0, 'ccMF')
# Text(0.5, 1.0, 'ccMF')

# %%
ys = ecmf.to_numpy()
ecmf.plot.box()
#pylt.boxplot(ys)
q1 = ecmf.quantile(.25)
q3 = ecmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ecmf.median()):.2f} total deviation from median)')
        
pylt.title('ecMF')
# Out:
# Segmentation 9606490.0 is an outlier (1.01 total deviation from median)Segmentation 9606490.0 is an outlier (1.01 total deviation from median)
# Text(0.5, 1.0, 'ecMF')
# Text(0.5, 1.0, 'ecMF')

# %%
ys = plf.to_numpy()
plf.plot.box()
#pylt.boxplot(ys)
q1 = plf.quantile(.25)
q3 = plf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plf.median()):.2f} total deviation from median)')
        
pylt.title('pLF')
# Out:
# Segmentation 9230284.0 is an outlier (0.58 total deviation from median)
# Segmentation 9180558.0 is an outlier (0.57 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.58 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.55 total deviation from median)
# Segmentation 9458093.0 is an outlier (0.64 total deviation from median)
# Segmentation 9467252.0 is an outlier (0.76 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.70 total deviation from median)
# Segmentation 9230284.0 is an outlier (0.58 total deviation from median)
# Segmentation 9180558.0 is an outlier (0.57 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.58 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.55 total deviation from median)
# Segmentation 9458093.0 is an outlier (0.64 total deviation from median)
# Segmentation 9467252.0 is an outlier (0.76 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.70 total deviation from median)
# Text(0.5, 1.0, 'pLF')
# Text(0.5, 1.0, 'pLF')

# %%
ys = pmf.to_numpy()
pmf.plot.box()
#pylt.boxplot(ys)
q1 = pmf.quantile(.25)
q3 = pmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmf.median()):.2f} total deviation from median)')
        
pylt.title('pMF')
# Out:
# Segmentation 9211049.0 is an outlier (0.74 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.07 total deviation from median)Segmentation 9211049.0 is an outlier (0.74 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.07 total deviation from median)
# Segmentation 9504627.0 is an outlier (0.74 total deviation from median)
# Segmentation 9120941.0 is an outlier (0.75 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.85 total deviation from median)
#
# Segmentation 9504627.0 is an outlier (0.74 total deviation from median)
# Segmentation 9120941.0 is an outlier (0.75 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.85 total deviation from median)
# Text(0.5, 1.0, 'pMF')
# Text(0.5, 1.0, 'pMF')

# %%
ys = alf.to_numpy()
alf.plot.box()
#pylt.boxplot(ys)
q1 = alf.quantile(.25)
q3 = alf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alf.median()):.2f} total deviation from median)')
        
pylt.title('aLF')
# Out:
# Segmentation 9606490.0 is an outlier (0.89 total deviation from median)Segmentation 9606490.0 is an outlier (0.89 total deviation from median)
# Segmentation 9474901.0 is an outlier (0.81 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.23 total deviation from median)
# Segmentation 9302260.0 is an outlier (0.98 total deviation from median)
#
# Segmentation 9474901.0 is an outlier (0.81 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.23 total deviation from median)
# Segmentation 9302260.0 is an outlier (0.98 total deviation from median)
# Text(0.5, 1.0, 'aLF')
# Text(0.5, 1.0, 'aLF')

# %%
ys = amf.to_numpy()
amf.plot.box()
#pylt.boxplot(ys)
q1 = amf.quantile(.25)
q3 = amf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amf.median()):.2f} total deviation from median)')
        
pylt.title('aMF')
# Out:
# Segmentation 9606490.0 is an outlier (1.44 total deviation from median)Segmentation 9606490.0 is an outlier (1.44 total deviation from median)
# Segmentation 9322401.0 is an outlier (1.18 total deviation from median)
#
# Segmentation 9322401.0 is an outlier (1.18 total deviation from median)
# Text(0.5, 1.0, 'aMF')
# Text(0.5, 1.0, 'aMF')

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
elt.plot.box()
#pylt.boxplot(ys)
q1 = elt.quantile(.25)
q3 = elt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - elt.median()):.2f} total deviation from median)')
        
pylt.title('eLT')
# Out:
# Segmentation 9222973.0 is an outlier (0.92 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.15 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.86 total deviation from median)
# Segmentation 9222973.0 is an outlier (0.92 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.15 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.86 total deviation from median)
# Text(0.5, 1.0, 'eLT')
# Text(0.5, 1.0, 'eLT')

# %%
ys = plt.to_numpy()
plt.plot.box()
#pylt.boxplot(ys)
q1 = plt.quantile(.25)
q3 = plt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plt.median()):.2f} total deviation from median)')
        
pylt.title('pLT')
# Out:
# Segmentation 9862541.0 is an outlier (0.94 total deviation from median)
# Segmentation 9862541.0 is an outlier (0.94 total deviation from median)
# Text(0.5, 1.0, 'pLT')
# Text(0.5, 1.0, 'pLT')

# %%
ys = ilt.to_numpy()
ilt.plot.box()
#pylt.boxplot(ys)
q1 = ilt.quantile(.25)
q3 = ilt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ilt.median()):.2f} total deviation from median)')
        
pylt.title('iLT')
# Out:
# Segmentation 9458093.0 is an outlier (1.41 total deviation from median)
# Segmentation 9122643.0 is an outlier (1.14 total deviation from median)
# Segmentation 9035647.0 is an outlier (1.26 total deviation from median)
# Segmentation 9458093.0 is an outlier (1.41 total deviation from median)
# Segmentation 9122643.0 is an outlier (1.14 total deviation from median)
# Segmentation 9035647.0 is an outlier (1.26 total deviation from median)
# Text(0.5, 1.0, 'iLT')
# Text(0.5, 1.0, 'iLT')

# %%
ys = alt.to_numpy()
alt.plot.box()
#pylt.boxplot(ys)
q1 = alt.quantile(.25)
q3 = alt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alt.median()):.2f} total deviation from median)')
        
pylt.title('aLT')
# Out:
# Segmentation 9302260.0 is an outlier (1.20 total deviation from median)
# Segmentation 9115742.0 is an outlier (1.16 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.20 total deviation from median)
# Segmentation 9115742.0 is an outlier (1.16 total deviation from median)
# Text(0.5, 1.0, 'aLT')
# Text(0.5, 1.0, 'aLT')

# %%
ys = clt.to_numpy()
clt.plot.box()
#pylt.boxplot(ys)
q1 = clt.quantile(.25)
q3 = clt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - clt.median()):.2f} total deviation from median)')
        
pylt.title('cLT')
# Out:
# Segmentation 9302260.0 is an outlier (1.62 total deviation from median)
# Segmentation 9034644.0 is an outlier (1.60 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.62 total deviation from median)
# Segmentation 9034644.0 is an outlier (1.60 total deviation from median)
# Text(0.5, 1.0, 'cLT')
# Text(0.5, 1.0, 'cLT')

# %%
ys = emt.to_numpy()
emt.plot.box()
#pylt.boxplot(ys)
q1 = emt.quantile(.25)
q3 = emt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - emt.median()):.2f} total deviation from median)')
        
pylt.title('eMT')
# Out:
# Segmentation 9606490.0 is an outlier (0.84 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.78 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.84 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.78 total deviation from median)
# Text(0.5, 1.0, 'eMT')
# Text(0.5, 1.0, 'eMT')

# %%
ys = pmt.to_numpy()
pmt.plot.box()
#pylt.boxplot(ys)
q1 = pmt.quantile(.25)
q3 = pmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmt.median()):.2f} total deviation from median)')
        
pylt.title('pMT')
# Out:
# Segmentation 9606490.0 is an outlier (0.69 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.87 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.75 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.69 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.87 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.75 total deviation from median)
# Text(0.5, 1.0, 'pMT')
# Text(0.5, 1.0, 'pMT')

# %%
ys = imt.to_numpy()
imt.plot.box()
#pylt.boxplot(ys)
q1 = imt.quantile(.25)
q3 = imt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - imt.median()):.2f} total deviation from median)')
        
pylt.title('iMT')
# Out:
# Segmentation 9223980.0 is an outlier (1.31 total deviation from median)Segmentation 9223980.0 is an outlier (1.31 total deviation from median)
# Segmentation 9867315.0 is an outlier (0.63 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.06 total deviation from median)
# Segmentation 9531454.0 is an outlier (0.73 total deviation from median)
# Segmentation 9355228.0 is an outlier (0.65 total deviation from median)
# Segmentation 9035647.0 is an outlier (0.61 total deviation from median)
# Segmentation 9019287.0 is an outlier (0.59 total deviation from median)
# Segmentation 9005075.0 is an outlier (0.69 total deviation from median)
#
# Segmentation 9867315.0 is an outlier (0.63 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.06 total deviation from median)
# Segmentation 9531454.0 is an outlier (0.73 total deviation from median)
# Segmentation 9355228.0 is an outlier (0.65 total deviation from median)
# Segmentation 9035647.0 is an outlier (0.61 total deviation from median)
# Segmentation 9019287.0 is an outlier (0.59 total deviation from median)
# Segmentation 9005075.0 is an outlier (0.69 total deviation from median)
# Text(0.5, 1.0, 'iMT')
# Text(0.5, 1.0, 'iMT')

# %%
ys = amt.to_numpy()
amt.plot.box()
#pylt.boxplot(ys)
q1 = amt.quantile(.25)
q3 = amt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amt.median()):.2f} total deviation from median)')
        
pylt.title('aMT')
# Out:
# Segmentation 9606490.0 is an outlier (1.38 total deviation from median)
# Segmentation 9471287.0 is an outlier (1.14 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.38 total deviation from median)
# Segmentation 9471287.0 is an outlier (1.14 total deviation from median)
# Text(0.5, 1.0, 'aMT')
# Text(0.5, 1.0, 'aMT')

# %%
ys = cmt.to_numpy()
cmt.plot.box()
#pylt.boxplot(ys)
q1 = cmt.quantile(.25)
q3 = cmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cmt.median()):.2f} total deviation from median)')
        
pylt.title('cMT')
# Out:
# Text(0.5, 1.0, 'cMT')
# Text(0.5, 1.0, 'cMT')

# %%
df.boxplot(column=['ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
       'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT', 'aMT',
       'cMT'], figsize=(20,20))
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
