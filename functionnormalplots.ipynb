# %%
from matplotlib import pyplot as pylt
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy import stats

# %%
df = pd.read_csv('C:/Users/simon/Desktop/Ergebnisse/function_normals.csv')

# %%
df.head()
# Out:
#          dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498.0  1.612626  2.423014  1.470498  2.069139  2.916025  1.976808
# 1  9211751.0  1.438413  2.482691  1.804538  1.868150  2.879939  2.024902
# 2  9230284.0  1.464516  2.307128  1.249868  1.675049  1.978149  1.461626
# 3  9156526.0  1.258032  2.036302  1.529223  1.393183  2.289310  2.037210
# 4  9246518.0  1.400533  2.341231  1.736087  1.910290  2.420715  1.838844
#
#         pLF       pMF       aLF  ...  pLF.aMiv   cLT.aSD  cLT.aMav  cLT.aMiv  \
# 0  2.372228  2.524581  2.655239  ...  0.860532  0.594717  3.446554  1.065954
# 1  2.482513  2.531772  3.491224  ...  0.990934  0.540850  2.766902  0.637682
# 2  2.578808  1.883364  3.026678  ...  0.543643  0.381298  2.674789  1.133064
# 3  2.297326  2.288112  2.352435  ...  0.765743  0.269025  1.569904  0.807036
# 4  2.540592  2.557686  2.735113  ...  0.458085  0.716855  2.923285  0.431379
#
#     aMF.aSD  aMF.aMav  aMF.aMiv   iMT.aSD  iMT.aMav  iMT.aMiv
# 0  0.756348  5.579643  0.744871  0.627437  2.731788  0.449299
# 1  0.748433  4.028896  0.620827  0.558141  2.651946  0.470064
# 2  0.977309  5.638954  0.503010  0.629242  3.058631  0.518640
# 3  0.596932  3.951042  0.530762  0.634636  2.722663  0.390471
# 4  0.724103  4.042306  0.589106  0.723856  3.145205  0.466355
#
# [5 rows x 81 columns]

# %% [markdown]
# Fill NaN values with overall dataset mean.

# %%
#print(f'Filling {df[df.isna().any(axis=1)].shape[0]} instances containing NaN values.')

# %%
#d = defaultdict()
#for column in df.columns:
#    d[column] = df[column].mean()

# %%
#df.fillna(value=d, inplace=True)

# %% [markdown]
# Filter out extreme outliers (deviating more than 5 standard deviations from the mean).

# %%
#numrows = df.shape[0]
#df = df[(np.abs(stats.zscore(df)) < 5).all(axis=1)]
#print(f'Filtered out {numrows - df.shape[0]} instances.')

# %%
df = df.loc[df['dir'] != 9189303].loc[df['dir'] != 9539084]

# %%
df.columns
# Out:
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'cMT.aSD', 'cMT.aMav', 'cMT.aMiv', 'iLT.aSD', 'iLT.aMav',
#        'iLT.aMiv', 'eMT.aSD', 'eMT.aMav', 'eMT.aMiv', 'ccLF.aSD', 'ccLF.aMav',
#        'ccLF.aMiv', 'pLT.aSD', 'pLT.aMav', 'pLT.aMiv', 'icMF.aSD', 'icMF.aMav',
#        'icMF.aMiv', 'ecMF.aSD', 'ecMF.aMav', 'ecMF.aMiv', 'icLF.aSD',
#        'icLF.aMav', 'icLF.aMiv', 'pMT.aSD', 'pMT.aMav', 'pMT.aMiv', 'aLF.aSD',
#        'aLF.aMav', 'aLF.aMiv', 'ccMF.aSD', 'ccMF.aMav', 'ccMF.aMiv',
#        'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv', 'eLT.aSD', 'eLT.aMav', 'eLT.aMiv',
#        'aLT.aSD', 'aLT.aMav', 'aLT.aMiv', 'pMF.aSD', 'pMF.aMav', 'pMF.aMiv',
#        'aMT.aSD', 'aMT.aMav', 'aMT.aMiv', 'pLF.aSD', 'pLF.aMav', 'pLF.aMiv',
#        'cLT.aSD', 'cLT.aMav', 'cLT.aMiv', 'aMF.aSD', 'aMF.aMav', 'aMF.aMiv',
#        'iMT.aSD', 'iMT.aMav', 'iMT.aMiv'],
#       dtype='object')

# %%
eclf = df['ecLF']
cclf = df['ccLF']
iclf = df['icLF']
icmf = df['icMF']
ccmf = df['ccMF']
ecmf = df['ecMF']

elt = df['eLT']
plt = df['pLT']
ilt = df['iLT']
alt = df['aLT']
clt = df['cLT']

emt = df['eMT']
pmt = df['pMT']
imt = df['iMT']
amt = df['aMT']
cmt = df['cMT']

plf = df['pLF']
pmf = df['pMF']
alf = df['aLF']
amf = df['aMF']

# %%
xs = np.arange(0, df.shape[0])
len(xs)
# Out:
# 475

# %% [markdown]
# # Mesh

# %% [markdown]
# ## Subregion scatters

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = iclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = icmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ccmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ecmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMF')
for i in range(len(xs)):
    pass

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('plt')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ilt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = clt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = emt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = imt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %% [markdown]
# ## Subregion boxplots

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
eclf.plot.box()
#pylt.boxplot(ys)
q1 = eclf.quantile(.25)
q3 = eclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - eclf.median()):.2f} total deviation from median)')
        
pylt.title('ecLF')
# Out:
# Segmentation 9750090.0 is an outlier (1.36 total deviation from median)
# Segmentation 9395979.0 is an outlier (1.20 total deviation from median)
# Segmentation 9341240.0 is an outlier (1.24 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.53 total deviation from median)
# Segmentation 9102858.0 is an outlier (1.18 total deviation from median)
# Segmentation 9130672.0 is an outlier (1.29 total deviation from median)
# Text(0.5, 1.0, 'ecLF')

# %%
ys = cclf.to_numpy()
cclf.plot.box()
#pylt.boxplot(ys)
q1 = cclf.quantile(.25)
q3 = cclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cclf.median()):.2f} total deviation from median)')
        
pylt.title('ccLF')
# Out:
# Text(0.5, 1.0, 'ccLF')

# %%
ys = iclf.to_numpy()
iclf.plot.box()
#pylt.boxplot(ys)
q1 = iclf.quantile(.25)
q3 = iclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - iclf.median()):.2f} total deviation from median)')
        
pylt.title('icLF')
# Out:
# Segmentation 9215922.0 is an outlier (1.07 total deviation from median)
# Segmentation 9988421.0 is an outlier (0.95 total deviation from median)
# Segmentation 9943227.0 is an outlier (1.17 total deviation from median)
# Segmentation 9908089.0 is an outlier (1.08 total deviation from median)
# Segmentation 9745458.0 is an outlier (1.10 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.29 total deviation from median)
# Segmentation 9624170.0 is an outlier (1.13 total deviation from median)
# Segmentation 9441432.0 is an outlier (1.02 total deviation from median)
# Segmentation 9329062.0 is an outlier (0.96 total deviation from median)
# Segmentation 9341240.0 is an outlier (1.06 total deviation from median)
# Segmentation 9049223.0 is an outlier (0.94 total deviation from median)
# Segmentation 9053047.0 is an outlier (0.96 total deviation from median)
# Segmentation 9101066.0 is an outlier (1.07 total deviation from median)
# Text(0.5, 1.0, 'icLF')

# %%
ys = icmf.to_numpy()
icmf.plot.box()
#pylt.boxplot(ys)
q1 = icmf.quantile(.25)
q3 = icmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - icmf.median()):.2f} total deviation from median)')
        
pylt.title('icMF')
# Out:
# Segmentation 9180558.0 is an outlier (1.09 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.89 total deviation from median)
# Segmentation 9766939.0 is an outlier (0.82 total deviation from median)
# Segmentation 9672573.0 is an outlier (1.02 total deviation from median)
# Segmentation 9517311.0 is an outlier (1.28 total deviation from median)
# Segmentation 9375317.0 is an outlier (0.90 total deviation from median)
# Segmentation 9329062.0 is an outlier (1.29 total deviation from median)
# Segmentation 9332345.0 is an outlier (0.82 total deviation from median)
# Segmentation 9393987.0 is an outlier (1.19 total deviation from median)
# Segmentation 9049223.0 is an outlier (1.06 total deviation from median)
# Segmentation 9091131.0 is an outlier (1.01 total deviation from median)
# Segmentation 9073948.0 is an outlier (0.81 total deviation from median)
# Segmentation 9101066.0 is an outlier (0.81 total deviation from median)
# Text(0.5, 1.0, 'icMF')

# %%
ys = ccmf.to_numpy()
ccmf.plot.box()
#pylt.boxplot(ys)
q1 = ccmf.quantile(.25)
q3 = ccmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ccmf.median()):.2f} total deviation from median)')
        
pylt.title('ccMF')
# Out:
# Segmentation 9241424.0 is an outlier (1.77 total deviation from median)
# Segmentation 9781749.0 is an outlier (1.80 total deviation from median)
# Segmentation 9691663.0 is an outlier (1.73 total deviation from median)
# Segmentation 9517311.0 is an outlier (1.64 total deviation from median)
# Segmentation 9329062.0 is an outlier (2.18 total deviation from median)
# Segmentation 9393987.0 is an outlier (1.71 total deviation from median)
# Segmentation 9048192.0 is an outlier (1.76 total deviation from median)
# Text(0.5, 1.0, 'ccMF')

# %%
ys = ecmf.to_numpy()
ecmf.plot.box()
#pylt.boxplot(ys)
q1 = ecmf.quantile(.25)
q3 = ecmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ecmf.median()):.2f} total deviation from median)')
        
pylt.title('ecMF')
# Out:
# Segmentation 9249025.0 is an outlier (1.39 total deviation from median)
# Segmentation 9241424.0 is an outlier (1.11 total deviation from median)
# Segmentation 9627197.0 is an outlier (1.10 total deviation from median)
# Segmentation 9781749.0 is an outlier (1.18 total deviation from median)
# Text(0.5, 1.0, 'ecMF')

# %%
ys = plf.to_numpy()
plf.plot.box()
#pylt.boxplot(ys)
q1 = plf.quantile(.25)
q3 = plf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plf.median()):.2f} total deviation from median)')
        
pylt.title('pLF')
# Out:
# Segmentation 9211049.0 is an outlier (0.71 total deviation from median)
# Segmentation 9160801.0 is an outlier (1.01 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.09 total deviation from median)
# Segmentation 9504627.0 is an outlier (0.72 total deviation from median)
# Segmentation 9316108.0 is an outlier (0.67 total deviation from median)
# Segmentation 9120941.0 is an outlier (0.73 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.83 total deviation from median)
# Text(0.5, 1.0, 'pLF')

# %%
ys = pmf.to_numpy()
pmf.plot.box()
#pylt.boxplot(ys)
q1 = pmf.quantile(.25)
q3 = pmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmf.median()):.2f} total deviation from median)')
        
pylt.title('pMF')
# Out:
# Segmentation 9230284.0 is an outlier (0.63 total deviation from median)
# Segmentation 9194012.0 is an outlier (0.64 total deviation from median)
# Segmentation 9162299.0 is an outlier (0.59 total deviation from median)
# Segmentation 9250756.0 is an outlier (0.62 total deviation from median)
# Segmentation 9249025.0 is an outlier (0.59 total deviation from median)
# Segmentation 9788072.0 is an outlier (0.58 total deviation from median)
# Segmentation 9598683.0 is an outlier (0.97 total deviation from median)
# Segmentation 9458093.0 is an outlier (0.69 total deviation from median)
# Segmentation 9422381.0 is an outlier (0.62 total deviation from median)
# Segmentation 9493245.0 is an outlier (0.95 total deviation from median)
# Segmentation 9326707.0 is an outlier (0.58 total deviation from median)
# Segmentation 9329062.0 is an outlier (0.70 total deviation from median)
# Segmentation 9396968.0 is an outlier (0.63 total deviation from median)
# Segmentation 9395979.0 is an outlier (0.85 total deviation from median)
# Segmentation 9316108.0 is an outlier (0.68 total deviation from median)
# Segmentation 9364366.0 is an outlier (0.58 total deviation from median)
# Segmentation 9341240.0 is an outlier (0.68 total deviation from median)
# Segmentation 9391984.0 is an outlier (0.60 total deviation from median)
# Segmentation 9330729.0 is an outlier (0.62 total deviation from median)
# Segmentation 9092628.0 is an outlier (0.70 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.74 total deviation from median)
# Segmentation 9024940.0 is an outlier (0.68 total deviation from median)
# Segmentation 9002430.0 is an outlier (0.61 total deviation from median)
# Segmentation 9001104.0 is an outlier (0.68 total deviation from median)
# Text(0.5, 1.0, 'pMF')

# %%
ys = alf.to_numpy()
alf.plot.box()
#pylt.boxplot(ys)
q1 = alf.quantile(.25)
q3 = alf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alf.median()):.2f} total deviation from median)')
        
pylt.title('aLF')
# Out:
# Segmentation 9606490.0 is an outlier (1.33 total deviation from median)
# Segmentation 9653075.0 is an outlier (2.56 total deviation from median)
# Segmentation 9461404.0 is an outlier (1.34 total deviation from median)
# Segmentation 9323079.0 is an outlier (1.71 total deviation from median)
# Segmentation 9102858.0 is an outlier (1.82 total deviation from median)
# Text(0.5, 1.0, 'aLF')

# %%
ys = amf.to_numpy()
amf.plot.box()
#pylt.boxplot(ys)
q1 = amf.quantile(.25)
q3 = amf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amf.median()):.2f} total deviation from median)')
        
pylt.title('aMF')
# Out:
# Segmentation 9686590.0 is an outlier (1.07 total deviation from median)
# Segmentation 9598683.0 is an outlier (1.04 total deviation from median)
# Segmentation 9508335.0 is an outlier (1.32 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.15 total deviation from median)
# Segmentation 9395979.0 is an outlier (1.04 total deviation from median)
# Text(0.5, 1.0, 'aMF')

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
elt.plot.box()
#pylt.boxplot(ys)
q1 = elt.quantile(.25)
q3 = elt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - elt.median()):.2f} total deviation from median)')
        
pylt.title('eLT')
# Out:
# Segmentation 9223789.0 is an outlier (0.97 total deviation from median)
# Segmentation 9180558.0 is an outlier (0.70 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.84 total deviation from median)
# Segmentation 9566781.0 is an outlier (0.75 total deviation from median)
# Segmentation 9376280.0 is an outlier (0.70 total deviation from median)
# Segmentation 9397988.0 is an outlier (0.81 total deviation from median)
# Segmentation 9395979.0 is an outlier (0.85 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.78 total deviation from median)
# Segmentation 9130672.0 is an outlier (0.98 total deviation from median)
# Text(0.5, 1.0, 'eLT')

# %%
ys = plt.to_numpy()
plt.plot.box()
#pylt.boxplot(ys)
q1 = plt.quantile(.25)
q3 = plt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plt.median()):.2f} total deviation from median)')
        
pylt.title('pLT')
# Out:
# Segmentation 9154793.0 is an outlier (0.89 total deviation from median)
# Segmentation 9258562.0 is an outlier (0.83 total deviation from median)
# Segmentation 9152295.0 is an outlier (0.83 total deviation from median)
# Segmentation 9686590.0 is an outlier (0.89 total deviation from median)
# Segmentation 9933836.0 is an outlier (0.85 total deviation from median)
# Segmentation 9376280.0 is an outlier (0.76 total deviation from median)
# Segmentation 9314341.0 is an outlier (0.99 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.80 total deviation from median)
# Text(0.5, 1.0, 'pLT')

# %%
ys = ilt.to_numpy()
ilt.plot.box()
#pylt.boxplot(ys)
q1 = ilt.quantile(.25)
q3 = ilt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ilt.median()):.2f} total deviation from median)')
        
pylt.title('iLT')
# Out:
# Segmentation 9154793.0 is an outlier (1.05 total deviation from median)
# Segmentation 9223980.0 is an outlier (1.21 total deviation from median)
# Segmentation 9732959.0 is an outlier (0.98 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.97 total deviation from median)
# Segmentation 9987407.0 is an outlier (1.25 total deviation from median)
# Segmentation 9686590.0 is an outlier (1.18 total deviation from median)
# Segmentation 9395979.0 is an outlier (0.98 total deviation from median)
# Segmentation 9323079.0 is an outlier (0.99 total deviation from median)
# Segmentation 9023193.0 is an outlier (1.01 total deviation from median)
# Text(0.5, 1.0, 'iLT')

# %%
ys = alt.to_numpy()
alt.plot.box()
#pylt.boxplot(ys)
q1 = alt.quantile(.25)
q3 = alt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alt.median()):.2f} total deviation from median)')
        
pylt.title('aLT')
# Out:
# Segmentation 9606490.0 is an outlier (1.30 total deviation from median)
# Segmentation 9686590.0 is an outlier (1.11 total deviation from median)
# Segmentation 9493245.0 is an outlier (1.33 total deviation from median)
# Segmentation 9395979.0 is an outlier (1.35 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.27 total deviation from median)
# Text(0.5, 1.0, 'aLT')

# %%
ys = clt.to_numpy()
clt.plot.box()
#pylt.boxplot(ys)
q1 = clt.quantile(.25)
q3 = clt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - clt.median()):.2f} total deviation from median)')
        
pylt.title('cLT')
# Out:
# Segmentation 9817241.0 is an outlier (1.34 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.37 total deviation from median)
# Text(0.5, 1.0, 'cLT')

# %%
ys = emt.to_numpy()
emt.plot.box()
#pylt.boxplot(ys)
q1 = emt.quantile(.25)
q3 = emt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - emt.median()):.2f} total deviation from median)')
        
pylt.title('eMT')
# Out:
# Segmentation 9154793.0 is an outlier (1.30 total deviation from median)
# Segmentation 9222973.0 is an outlier (0.93 total deviation from median)
# Segmentation 9249025.0 is an outlier (1.22 total deviation from median)
# Segmentation 9493245.0 is an outlier (0.86 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.16 total deviation from median)
# Segmentation 9362660.0 is an outlier (0.87 total deviation from median)
# Segmentation 9311328.0 is an outlier (1.02 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.88 total deviation from median)
# Text(0.5, 1.0, 'eMT')

# %%
ys = pmt.to_numpy()
pmt.plot.box()
#pylt.boxplot(ys)
q1 = pmt.quantile(.25)
q3 = pmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmt.median()):.2f} total deviation from median)')
        
pylt.title('pMT')
# Out:
# Segmentation 9154793.0 is an outlier (1.56 total deviation from median)
# Segmentation 9862541.0 is an outlier (1.07 total deviation from median)
# Segmentation 9341240.0 is an outlier (1.06 total deviation from median)
# Text(0.5, 1.0, 'pMT')

# %%
ys = imt.to_numpy()
imt.plot.box()
#pylt.boxplot(ys)
q1 = imt.quantile(.25)
q3 = imt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - imt.median()):.2f} total deviation from median)')
        
pylt.title('iMT')
# Out:
# Segmentation 9154793.0 is an outlier (1.65 total deviation from median)
# Segmentation 9458093.0 is an outlier (1.42 total deviation from median)
# Segmentation 9369286.0 is an outlier (1.31 total deviation from median)
# Text(0.5, 1.0, 'iMT')

# %%
ys = amt.to_numpy()
amt.plot.box()
#pylt.boxplot(ys)
q1 = amt.quantile(.25)
q3 = amt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amt.median()):.2f} total deviation from median)')
        
pylt.title('aMT')
# Out:
# Segmentation 9249025.0 is an outlier (1.36 total deviation from median)
# Segmentation 9493245.0 is an outlier (1.20 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.18 total deviation from median)
# Segmentation 9311328.0 is an outlier (1.39 total deviation from median)
# Segmentation 9388068.0 is an outlier (1.45 total deviation from median)
# Text(0.5, 1.0, 'aMT')

# %%
ys = cmt.to_numpy()
cmt.plot.box()
#pylt.boxplot(ys)
q1 = cmt.quantile(.25)
q3 = cmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cmt.median()):.2f} total deviation from median)')
        
pylt.title('cMT')
# Out:
# Segmentation 9154793.0 is an outlier (2.69 total deviation from median)
# Segmentation 9249025.0 is an outlier (2.08 total deviation from median)
# Segmentation 9094693.0 is an outlier (2.01 total deviation from median)
# Text(0.5, 1.0, 'cMT')

# %%
df.boxplot(column=['ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
       'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT', 'aMT',
       'cMT'], figsize=(20,20))
# Out:
# <AxesSubplot:>
