# %%
from matplotlib import pyplot as pylt
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy import stats

# %%
df = pd.read_csv('C:/Users/simon/Desktop/Ergebnisse/function_normals_01.csv')

# %%
df.head()
# Out:
#        dir      ecLF      ccLF      icLF      ecMF      ccMF      icMF  \
# 0  9162498  2.069139  2.916025  1.976808  1.612626  2.423014  1.470498
# 1  9211751  1.868150  2.879939  2.024902  1.438413  2.482691  1.804538
# 2  9230284  1.675049  1.978149  1.461626  1.464516  2.307128  1.249868
# 3  9156526  1.393183  2.289310  2.037210  1.258032  2.036302  1.529223
# 4  9197994  2.003260  3.346352  2.369594  1.808771  2.940873  1.449021
#
#         pLF       pMF       aLF  ...  ecLF.aMiv   pLT.aSD  pLT.aMav  pLT.aMiv  \
# 0  4.172768  5.116452  2.060932  ...   1.082630  0.444685  3.190892  1.310588
# 1  3.876015  9.390634  2.308903  ...   0.981359  0.381429  2.891728  1.235181
# 2  3.547588  5.073966  2.618153  ...   0.995205  0.452363  2.411222  0.524113
# 3  3.959209  4.519392  2.001159  ...   0.558312  0.493070  2.761219  0.712944
# 4  4.301546  7.519571  2.374646  ...   0.964691  0.409921  2.817011  0.944542
#
#     aLF.aSD  aLF.aMav  aLF.aMiv  icMF.aSD  icMF.aMav  icMF.aMiv
# 0  0.756348  5.579643  0.744871  0.278746   1.936522   1.003673
# 1  0.748433  4.028896  0.620827  0.390065   2.551111   1.095140
# 2  0.977309  5.638954  0.503010  0.274034   1.803675   0.729488
# 3  0.596932  3.951042  0.530762  0.313622   2.114356   0.815232
# 4  0.715628  4.859161  0.696313  0.353431   2.163058   0.920863
#
# [5 rows x 81 columns]

# %% [markdown]
# Fill NaN values with overall dataset mean.

# %%
#print(f'Filling {df[df.isna().any(axis=1)].shape[0]} instances containing NaN values.')

# %%
#d = defaultdict()
#for column in df.columns:
#    d[column] = df[column].mean()

# %%
#df.fillna(value=d, inplace=True)

# %% [markdown]
# Filter out extreme outliers (deviating more than 5 standard deviations from the mean).

# %%
#numrows = df.shape[0]
#df = df[(np.abs(stats.zscore(df)) < 5).all(axis=1)]
#print(f'Filtered out {numrows - df.shape[0]} instances.')

# %%
#df = df.loc[df['dir'] != 9189303].loc[df['dir'] != 9539084]

# %%
df.columns
# Out:
# Index(['dir', 'ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
#        'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT',
#        'aMT', 'cMT', 'cMT.aSD', 'cMT.aMav', 'cMT.aMiv', 'ecMF.aSD',
#        'ecMF.aMav', 'ecMF.aMiv', 'aMF.aSD', 'aMF.aMav', 'aMF.aMiv', 'iMT.aSD',
#        'iMT.aMav', 'iMT.aMiv', 'ccLF.aSD', 'ccLF.aMav', 'ccLF.aMiv', 'aLT.aSD',
#        'aLT.aMav', 'aLT.aMiv', 'icLF.aSD', 'icLF.aMav', 'icLF.aMiv', 'aMT.aSD',
#        'aMT.aMav', 'aMT.aMiv', 'cLT.aSD', 'cLT.aMav', 'cLT.aMiv', 'pLF.aSD',
#        'pLF.aMav', 'pLF.aMiv', 'ccMF.aSD', 'ccMF.aMav', 'ccMF.aMiv', 'pMT.aSD',
#        'pMT.aMav', 'pMT.aMiv', 'eMT.aSD', 'eMT.aMav', 'eMT.aMiv', 'pMF.aSD',
#        'pMF.aMav', 'pMF.aMiv', 'iLT.aSD', 'iLT.aMav', 'iLT.aMiv', 'eLT.aSD',
#        'eLT.aMav', 'eLT.aMiv', 'ecLF.aSD', 'ecLF.aMav', 'ecLF.aMiv', 'pLT.aSD',
#        'pLT.aMav', 'pLT.aMiv', 'aLF.aSD', 'aLF.aMav', 'aLF.aMiv', 'icMF.aSD',
#        'icMF.aMav', 'icMF.aMiv'],
#       dtype='object')

# %%
eclf = df['ecLF']
cclf = df['ccLF']
iclf = df['icLF']
icmf = df['icMF']
ccmf = df['ccMF']
ecmf = df['ecMF']

elt = df['eLT']
plt = df['pLT']
ilt = df['iLT']
alt = df['aLT']
clt = df['cLT']

emt = df['eMT']
pmt = df['pMT']
imt = df['iMT']
amt = df['aMT']
cmt = df['cMT']

plf = df['pLF']
pmf = df['pMF']
alf = df['aLF']
amf = df['aMF']

# %%
xs = np.arange(0, df.shape[0])
len(xs)
# Out:
# 160

# %% [markdown]
# ## Subregion scatters

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = iclf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = icmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('icMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ccmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ccMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ecmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('ecMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLF')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amf.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMF')
for i in range(len(xs)):
    pass

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = plt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('plt')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = ilt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = alt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = clt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cLT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = emt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('eMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = pmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('pMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = imt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('iMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = amt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('aMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %%
ys = cmt.to_numpy()
pylt.scatter(x=xs, y=ys)
pylt.title('cMT')
for i in range(len(xs)):
    pass
    # pylt.text(xs[i], ys[i], i)

# %% [markdown]
# ## Subregion boxplots

# %% [markdown]
# ### Femur

# %%
ys = eclf.to_numpy()
eclf.plot.box()
#pylt.boxplot(ys)
q1 = eclf.quantile(.25)
q3 = eclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - eclf.median()):.2f} total deviation from median)')
        
pylt.title('ecLF')
# Out:
# Segmentation 9241424.0 is an outlier (1.08 total deviation from median)
# Text(0.5, 1.0, 'ecLF')

# %%
ys = cclf.to_numpy()
cclf.plot.box()
#pylt.boxplot(ys)
q1 = cclf.quantile(.25)
q3 = cclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cclf.median()):.2f} total deviation from median)')
        
pylt.title('ccLF')
# Out:
# Segmentation 9241424.0 is an outlier (1.61 total deviation from median)
# Text(0.5, 1.0, 'ccLF')

# %%
ys = iclf.to_numpy()
iclf.plot.box()
#pylt.boxplot(ys)
q1 = iclf.quantile(.25)
q3 = iclf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - iclf.median()):.2f} total deviation from median)')
        
pylt.title('icLF')
# Out:
# Segmentation 9180558.0 is an outlier (1.03 total deviation from median)
# Segmentation 9241424.0 is an outlier (0.83 total deviation from median)
# Text(0.5, 1.0, 'icLF')

# %%
ys = icmf.to_numpy()
icmf.plot.box()
#pylt.boxplot(ys)
q1 = icmf.quantile(.25)
q3 = icmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - icmf.median()):.2f} total deviation from median)')
        
pylt.title('icMF')
# Out:
# Segmentation 9988421.0 is an outlier (0.98 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.26 total deviation from median)
# Segmentation 9905024.0 is an outlier (0.91 total deviation from median)
# Segmentation 9486827.0 is an outlier (0.94 total deviation from median)
# Segmentation 9036770.0 is an outlier (0.89 total deviation from median)
# Text(0.5, 1.0, 'icMF')

# %%
ys = ccmf.to_numpy()
ccmf.plot.box()
#pylt.boxplot(ys)
q1 = ccmf.quantile(.25)
q3 = ccmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ccmf.median()):.2f} total deviation from median)')
        
pylt.title('ccMF')
# Out:
# Segmentation 9988421.0 is an outlier (1.54 total deviation from median)
# Segmentation 9995338.0 is an outlier (1.08 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.52 total deviation from median)
# Segmentation 9905024.0 is an outlier (1.80 total deviation from median)
# Segmentation 9486827.0 is an outlier (1.23 total deviation from median)
# Segmentation 9355112.0 is an outlier (1.27 total deviation from median)
# Segmentation 9052956.0 is an outlier (1.36 total deviation from median)
# Text(0.5, 1.0, 'ccMF')

# %%
ys = ecmf.to_numpy()
ecmf.plot.box()
#pylt.boxplot(ys)
q1 = ecmf.quantile(.25)
q3 = ecmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ecmf.median()):.2f} total deviation from median)')
        
pylt.title('ecMF')
# Out:
# Segmentation 9606490.0 is an outlier (1.01 total deviation from median)
# Text(0.5, 1.0, 'ecMF')

# %%
ys = plf.to_numpy()
plf.plot.box()
#pylt.boxplot(ys)
q1 = plf.quantile(.25)
q3 = plf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plf.median()):.2f} total deviation from median)')
        
pylt.title('pLF')
# Out:
# Segmentation 9153509.0 is an outlier (2.92 total deviation from median)
# Segmentation 9223980.0 is an outlier (2.84 total deviation from median)
# Segmentation 9181790.0 is an outlier (3.10 total deviation from median)
# Segmentation 9157304.0 is an outlier (3.86 total deviation from median)
# Segmentation 9221040.0 is an outlier (4.08 total deviation from median)
# Segmentation 9545822.0 is an outlier (3.29 total deviation from median)
# Segmentation 9793168.0 is an outlier (5.75 total deviation from median)
# Segmentation 9574271.0 is an outlier (3.76 total deviation from median)
# Segmentation 9606490.0 is an outlier (3.22 total deviation from median)
# Segmentation 9768869.0 is an outlier (2.92 total deviation from median)
# Segmentation 9453274.0 is an outlier (6.27 total deviation from median)
# Segmentation 9324182.0 is an outlier (2.52 total deviation from median)
# Segmentation 9304351.0 is an outlier (3.80 total deviation from median)
# Segmentation 9120941.0 is an outlier (3.40 total deviation from median)
# Segmentation 9080864.0 is an outlier (6.19 total deviation from median)
# Segmentation 9013798.0 is an outlier (5.70 total deviation from median)
# Text(0.5, 1.0, 'pLF')

# %%
ys = pmf.to_numpy()
pmf.plot.box()
#pylt.boxplot(ys)
q1 = pmf.quantile(.25)
q3 = pmf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmf.median()):.2f} total deviation from median)')
        
pylt.title('pMF')
# Out:
# Segmentation 9191054.0 is an outlier (4.97 total deviation from median)
# Segmentation 9867315.0 is an outlier (4.13 total deviation from median)
# Segmentation 9302260.0 is an outlier (4.97 total deviation from median)
# Text(0.5, 1.0, 'pMF')

# %%
ys = alf.to_numpy()
alf.plot.box()
#pylt.boxplot(ys)
q1 = alf.quantile(.25)
q3 = alf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alf.median()):.2f} total deviation from median)')
        
pylt.title('aLF')
# Out:
# Segmentation 9606490.0 is an outlier (0.89 total deviation from median)
# Segmentation 9474901.0 is an outlier (0.81 total deviation from median)
# Segmentation 9504056.0 is an outlier (1.23 total deviation from median)
# Segmentation 9302260.0 is an outlier (0.98 total deviation from median)
# Text(0.5, 1.0, 'aLF')

# %%
ys = amf.to_numpy()
amf.plot.box()
#pylt.boxplot(ys)
q1 = amf.quantile(.25)
q3 = amf.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amf.median()):.2f} total deviation from median)')
        
pylt.title('aMF')
# Out:
# Segmentation 9606490.0 is an outlier (1.44 total deviation from median)
# Text(0.5, 1.0, 'aMF')

# %% [markdown]
# ### Tibia

# %%
ys = elt.to_numpy()
elt.plot.box()
#pylt.boxplot(ys)
q1 = elt.quantile(.25)
q3 = elt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - elt.median()):.2f} total deviation from median)')
        
pylt.title('eLT')
# Out:
# Segmentation 9222973.0 is an outlier (0.92 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.15 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.86 total deviation from median)
# Text(0.5, 1.0, 'eLT')

# %%
ys = plt.to_numpy()
plt.plot.box()
#pylt.boxplot(ys)
q1 = plt.quantile(.25)
q3 = plt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - plt.median()):.2f} total deviation from median)')
        
pylt.title('pLT')
# Out:
# Segmentation 9862541.0 is an outlier (0.95 total deviation from median)
# Text(0.5, 1.0, 'pLT')

# %%
ys = ilt.to_numpy()
ilt.plot.box()
#pylt.boxplot(ys)
q1 = ilt.quantile(.25)
q3 = ilt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - ilt.median()):.2f} total deviation from median)')
        
pylt.title('iLT')
# Out:
# Segmentation 9458093.0 is an outlier (1.41 total deviation from median)
# Segmentation 9122643.0 is an outlier (1.14 total deviation from median)
# Segmentation 9035647.0 is an outlier (1.26 total deviation from median)
# Text(0.5, 1.0, 'iLT')

# %%
ys = alt.to_numpy()
alt.plot.box()
#pylt.boxplot(ys)
q1 = alt.quantile(.25)
q3 = alt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - alt.median()):.2f} total deviation from median)')
        
pylt.title('aLT')
# Out:
# Segmentation 9606490.0 is an outlier (1.13 total deviation from median)
# Segmentation 9302260.0 is an outlier (1.20 total deviation from median)
# Segmentation 9115742.0 is an outlier (1.16 total deviation from median)
# Text(0.5, 1.0, 'aLT')

# %%
ys = clt.to_numpy()
clt.plot.box()
#pylt.boxplot(ys)
q1 = clt.quantile(.25)
q3 = clt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - clt.median()):.2f} total deviation from median)')
        
pylt.title('cLT')
# Out:
# Segmentation 9302260.0 is an outlier (1.62 total deviation from median)
# Segmentation 9003430.0 is an outlier (1.58 total deviation from median)
# Segmentation 9034644.0 is an outlier (1.61 total deviation from median)
# Text(0.5, 1.0, 'cLT')

# %%
ys = emt.to_numpy()
emt.plot.box()
#pylt.boxplot(ys)
q1 = emt.quantile(.25)
q3 = emt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - emt.median()):.2f} total deviation from median)')
        
pylt.title('eMT')
# Out:
# Segmentation 9180558.0 is an outlier (0.70 total deviation from median)
# Segmentation 9606490.0 is an outlier (0.84 total deviation from median)
# Segmentation 9471287.0 is an outlier (0.70 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.78 total deviation from median)
# Text(0.5, 1.0, 'eMT')

# %%
ys = pmt.to_numpy()
pmt.plot.box()
#pylt.boxplot(ys)
q1 = pmt.quantile(.25)
q3 = pmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - pmt.median()):.2f} total deviation from median)')
        
pylt.title('pMT')
# Out:
# Segmentation 9606490.0 is an outlier (0.69 total deviation from median)
# Segmentation 9003430.0 is an outlier (0.87 total deviation from median)
# Segmentation 9115742.0 is an outlier (0.75 total deviation from median)
# Text(0.5, 1.0, 'pMT')

# %%
ys = imt.to_numpy()
imt.plot.box()
#pylt.boxplot(ys)
q1 = imt.quantile(.25)
q3 = imt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - imt.median()):.2f} total deviation from median)')
        
pylt.title('iMT')
# Out:
# Segmentation 9223980.0 is an outlier (1.31 total deviation from median)
# Segmentation 9867315.0 is an outlier (0.63 total deviation from median)
# Segmentation 9606490.0 is an outlier (1.06 total deviation from median)
# Segmentation 9531454.0 is an outlier (0.73 total deviation from median)
# Segmentation 9355228.0 is an outlier (0.66 total deviation from median)
# Segmentation 9035647.0 is an outlier (0.61 total deviation from median)
# Segmentation 9019287.0 is an outlier (0.59 total deviation from median)
# Segmentation 9005075.0 is an outlier (0.69 total deviation from median)
# Text(0.5, 1.0, 'iMT')

# %%
ys = amt.to_numpy()
amt.plot.box()
#pylt.boxplot(ys)
q1 = amt.quantile(.25)
q3 = amt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - amt.median()):.2f} total deviation from median)')
        
pylt.title('aMT')
# Out:
# Segmentation 9606490.0 is an outlier (1.38 total deviation from median)
# Segmentation 9471287.0 is an outlier (1.14 total deviation from median)
# Text(0.5, 1.0, 'aMT')

# %%
ys = cmt.to_numpy()
cmt.plot.box()
#pylt.boxplot(ys)
q1 = cmt.quantile(.25)
q3 = cmt.quantile(.75)
ot = q3 + 1.5 * (q3 - q1)
ob = q1 - 1.5 * (q3 - q1)
for i, y in enumerate(ys):
    if y > ot or y < ob:
        pylt.text(1, y, df.iloc[i]['dir'])
        print(f'Segmentation {df.iloc[i]["dir"]} is an outlier ({abs(y - cmt.median()):.2f} total deviation from median)')
        
pylt.title('cMT')
# Out:
# Text(0.5, 1.0, 'cMT')

# %%
df.boxplot(column=['ecLF', 'ccLF', 'icLF', 'ecMF', 'ccMF', 'icMF', 'pLF', 'pMF',
       'aLF', 'aMF', 'eLT', 'pLT', 'iLT', 'aLT', 'cLT', 'eMT', 'pMT', 'iMT', 'aMT',
       'cMT'], figsize=(20,20))
# Out:
# <AxesSubplot:>
